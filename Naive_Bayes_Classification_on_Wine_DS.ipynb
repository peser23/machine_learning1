# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine

wine = load_wine()

# %%
dir(wine)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
wine.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
#create the wine dataset
df = pd.DataFrame(data=wine.data,columns=wine.feature_names)
df['target'] = wine.target

# %% [markdown]
# ###Split the data

# %%
from sklearn.model_selection import train_test_split

inputs = df.drop(columns=['target'], axis='columns')
X_train, X_test, y_train, y_test = train_test_split(inputs, df['target'], test_size=0.20, random_state=7852)

# %%
len(X_test)
# Out:
# 36

# %% [markdown]
# ###Apply the Naive Bayes classifier

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.9722222222222222
